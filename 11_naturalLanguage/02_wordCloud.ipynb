# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# %matplotlib inline
# 한글폰트 사용
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# Alice in Wonderland

# %%
text = open('./data/Alice.txt').read()
stopwords = set(STOPWORDS)
stopwords.add('said')

# %%
print(stopwords)
# Out:
# {'is', 'of', "mustn't", 'further', 'her', 'should', 'below', "don't", 'any', 'else', "we'd", 'at', "it's", "hasn't", 'when', 'why', 'how', 'themselves', 'myself', 'few', 'himself', "doesn't", "shouldn't", "wouldn't", "he'll", "how's", 'cannot', 'then', 'down', 'have', "i'll", 'since', 'above', 'all', "he's", 'each', 'do', "she's", 'here', 'has', "couldn't", 'an', 'i', "she'd", 'he', 'yourself', 'like', 'my', 'we', 'yours', 'having', 'own', 'theirs', 'both', 'if', 'me', 'this', 'too', "when's", 'his', 'she', "aren't", 'shall', 'they', "why's", 'just', 'had', 'herself', 'it', "won't", 'those', 'or', 'again', 'get', 'could', 'you', 'ours', 'does', 'what', "you'd", 'r', 'hence', 'over', 'their', "you've", "she'll", "hadn't", 'its', 'k', "he'd", 'with', 'there', "i'd", 'in', 'however', "isn't", 'a', 'be', 'during', 'www', 'after', 'such', 'did', 'through', 'nor', 'to', "where's", "we'll", 'other', 'while', 'than', "weren't", "here's", "they'd", 'more', 'out', 'that', "let's", 'once', 'who', 'com', 'and', 'therefore', 'up', 'not', 'for', 'can', 'before', 'until', 'yourselves', 'most', 'ever', "haven't", 'also', 'under', 'am', 'are', 'into', 'no', 'been', 'by', 'between', 'only', 'ourselves', "there's", 'which', 'was', 'where', "i've", "you'll", "can't", "that's", 'them', "they're", 'because', 'some', 'said', 'him', 'so', 'the', 'very', 'were', 'whom', 'itself', 'same', 'hers', 'ought', "we're", 'otherwise', 'doing', 'our', "who's", 'off', 'would', "shan't", "they'll", 'against', "they've", 'from', "we've", 'these', "didn't", "wasn't", 'http', "i'm", 'as', 'about', 'but', 'on', 'being', 'your', "what's", "you're"}

# %%
wc = WordCloud(background_color='white', max_words=2000, stopwords=stopwords)
wc = wc.generate(text)

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]}: {values[i]}')
# Out:
# Alice: 1.0
# little: 0.29508196721311475
# one: 0.27595628415300544
# know: 0.2459016393442623
# went: 0.226775956284153
# thing: 0.2185792349726776
# time: 0.2103825136612022
# Queen: 0.20765027322404372
# see: 0.1830601092896175
# King: 0.17486338797814208

# %%
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
mask = np.array(Image.open('./data/Alice_mask.png'))

plt.figure(figsize=(8,8))
plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=mask, stopwords=stopwords)
wc = wc.generate(text)

# %%
plt.figure(figsize=(8,8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Star Wars - A New Hope

# %%
text = open('./data/A_new_hope.txt').read()
text = text.replace('HAN', 'Han')
text = text.replace("LUKE'S", 'Luke')

mask = np.array(Image.open('./data/Stormtrooper_mask.png'))

# %%
stopwords = set(STOPWORDS)
stopwords.add('int')
stopwords.add('ext')

# %%
wc = WordCloud(max_words=1000, mask=mask, stopwords=stopwords,
               margin=10, random_state=1).generate(text)
default_colors = wc.to_array()

# %%
import random
def grey_color(word, font_size, position, orientation,
               random_state=None, **kwargs):
    return 'hsl(0, 0%%, %d%%)' % random.randint(60,100)     # hue, saturation, lightness

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color, random_state=3), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]}: {values[i]}')
# Out:
# Luke: 1.0
# Han: 0.45121951219512196
# DEATH STAR: 0.3902439024390244
# THREEPIO: 0.36585365853658536
# Ben: 0.2665505226480836
# Leia: 0.19686411149825783
# ship: 0.19686411149825783
# Artoo: 0.17247386759581881
# one: 0.1672473867595819
# X WING: 0.16550522648083624
